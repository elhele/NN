# %% [markdown]
# Constants

# %%
from numpy import linalg as LA
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline 

#constants:

sigma = 2
r_xd = np.array([0.8182, 0.354])
r_x = np.array([[1, 0.8182],[0.8182,1]])
eta1 = 0.3
eta2 = 1.0
print r_x[1,0]
# Out:
# 0.8182

# %% [markdown]
# Cost function

# %%
w1 = np.arange(-10., 10, 0.2)
w2 = np.arange(-10., 10, 0.2)
w = np.column_stack((w1,w2)).T
 

fig = plt.figure()
ax = fig.gca(projection='3d')
w1 = np.arange(-5, 5, 0.25)
w1len = len(w1)
w2 = np.arange(-5, 5, 0.25)
w2len = len(w2)
w1, w2 = np.meshgrid(w1, w2)
E = 0.5*sigma**2 - w1*r_xd[0]- w2*r_xd[1] + 0.5*(w1*(w1*r_x[0,0] + w2*r_x[1,0]) + w2*(w1*r_x[0,1] + w2*r_x[1,1]))

colortuple = ('w', 'b')
colors = np.empty(w1.shape, dtype=str)
for y in range(w2len):
    for x in range(w1len):
        colors[x, y] = colortuple[(x + y) % len(colortuple)]

surf = ax.plot_surface(w1, w2, E, rstride=1, cstride=1, facecolors=colors,
                       linewidth=0, antialiased=False)

ax.set_zlim3d(-10, 10)
ax.w_zaxis.set_major_locator(LinearLocator(6))

plt.show()

# %%
def steepest_descent(eta):
    err = 100
    #estimate from plot above:
    w_init = np.array([-2,2])
    w = w_init
    weights = np.array([[]])
    Es = np.array([])
    iterations = 0

    while(abs(err) > 0.0001):
        iterations += 1
        E = 0.5*sigma**2 - w[0]*r_xd[0]- w[1]*r_xd[1] + 0.5*(w[0]*(w[0]*r_x[0,0] + w[1]*r_x[1,0])
                                                             + w[1]*(w[0]*r_x[0,1] + w[1]*r_x[1,1]))
        g = r_xd - np.dot(R_x,w)
        E_upd = E - eta * (LA.norm(g))**2
        w_upd = w - eta * g
        weights = np.append(weights, w)
        Es = np.append(Es,E)
        err = w_upd - w
        w = w_upd
    print "minimum weight"
    print w   
    print "number of iterations"
    print iterations

# %% [markdown]
# Path, $\eta = 0.3$

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()

# %% [markdown]
# Path, $\eta = 0.01$

# %%
steepest_descent(eta_small)
# Out:
# minimum weight
# 0.752326375959
# number of iterations
# 154

# %% [markdown]
# Path, $\eta = 0.45$

# %%
steepest_descent(eta_large)
# Out:
# minimum weight
# 0.750043556143
# number of iterations
# 46

# %%
steepest_descent(0.49)
# Out:
# minimum weight
# 0.749951866545
# number of iterations
# 249
